# %% [markdown]
# Unet-multi

# %%
# !git clone https://github.com/zonasw/unet-nested-multiple-classification.git
# Out:
# fatal: destination path 'unet-nested-multiple-classification' already exists and is not an empty directory.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -r /content/drive/MyDrive/research/ML-OCT_datasets/oct5k_prepared/exp1/test_img /content/unet-nested-multiple-classification/data
# !cp -r /content/drive/MyDrive/research/ML-OCT_datasets/oct5k_prepared/exp1/test_msk /content/unet-nested-multiple-classification/data
# Out:
# ^C
# ^C
