# %%
import matplotlib.pyplot as plt

# %%
plt.subplot(221)
nos = [20,20,20]
labels = ['AMD', 'DME', 'Normal']
plt.pie(nos, labels=labels, startangle=90)
plt.title('volumes for each condition (total:60)')

plt.subplot(223)
nos = [722,422,530]
labels = ['AMD', 'DME', 'Normal']
plt.pie(nos, labels=labels, startangle=90)
plt.title('scans for each condition (total:1672)')

plt.subplot(222)
nos = [100]
labels = ['Spectralis']
plt.pie(nos,labels=labels)
plt.title('OCT device')

plt.tight_layout()
plt.show()

# %%
# Info about prepared dataset from the scripts
plt.subplot(211)
nos = [48,5,7]
labels = ['train', 'val', 'test']
plt.pie(nos, labels=labels, startangle=90)
plt.title('train/val/test by volumes (total:60)')

plt.subplot(212)
nos = [1260,105,307]
labels = ['train', 'val', 'test']
plt.pie(nos, labels=labels, startangle=90)
plt.title('train/val/test by images (total:{})'.format(sum(nos)))

plt.show()
