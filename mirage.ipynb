# %%
# !git clone https://github.com/j-morano/MIRAGE.git
# Out:
# Cloning into 'MIRAGE'...
# remote: Enumerating objects: 201, done.
# remote: Counting objects: 100% (71/71), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 201 (delta 49), reused 36 (delta 33), pack-reused 130 (from 1)
# Receiving objects: 100% (201/201), 530.66 KiB | 16.08 MiB/s, done.
# Resolving deltas: 100% (84/84), done.

# %%
# %cd MIRAGE
# Out:
# /content/MIRAGE

# %%
# !./prepare_env.py
# Out:
# Streaming output truncated to the last 5000 lines.
# Python-3.10.16/Lib/test/cjkencodings/cp949.txt
# Python-3.10.16/Lib/test/cjkencodings/euc_jisx0213-utf8.txt
# Python-3.10.16/Lib/test/cjkencodings/euc_jisx0213.txt
# Python-3.10.16/Lib/test/cjkencodings/euc_jp-utf8.txt
# Python-3.10.16/Lib/test/cjkencodings/euc_jp.txt
# Python-3.10.16/Lib/test/cjkencodings/euc_kr-utf8.txt
# Python-3.10.16/Lib/test/cjkencodings/euc_kr.txt
# Python-3.10.16/Lib/test/cjkencodings/gb18030-utf8.txt
# Python-3.10.16/Lib/test/cjkencodings/gb18030.txt
# Python-3.10.16/Lib/test/cjkencodings/gb2312-utf8.txt
# Python-3.10.16/Lib/test/cjkencodings/gb2312.txt
# Python-3.10.16/Lib/test/cjkencodings/gbk-utf8.txt
# Python-3.10.16/Lib/test/cjkencodings/gbk.txt
# Python-3.10.16/Lib/test/cjkencodings/hz-utf8.txt
# Python-3.10.16/Lib/test/cjkencodings/hz.txt
# Python-3.10.16/Lib/test/cjkencodings/iso2022_jp-utf8.txt
# Python-3.10.16/Lib/test/cjkencodings/iso2022_jp.txt
# ...

# %%
# !python mirage_wrapper.py
# Out:
# Creating model: pretrain_multimae_base for inputs ['bscan', 'slo', 'bscanlayermap'] and outputs ['bscan', 'slo', 'bscanlayermap']
# Image size: (512, 512), Patch size: (32, 32)
# Image size: (512, 512), Patch size: (32, 32)
# Image size: (128, 128), Patch size: (8, 8)
# Building 2D sincos posemb with h=16 and w=16
# Building 2D sincos posemb with h=16 and w=16
# Building 2D sincos posemb with h=16 and w=16
#   Missing keys: 0
#   Unexpected keys: 0
# Using device: cpu
# Input: bscan torch.float32 torch.Size([1, 1, 512, 512]) tensor(0.) tensor(0.8627)
# Input: slo torch.float32 torch.Size([1, 1, 512, 512]) tensor(0.) tensor(0.9961)
# Input: bscanlayermap torch.int64 torch.Size([1, 128, 128]) tensor(0) tensor(11)
# Input: bscan torch.Size([1, 1, 512, 512]) tensor(0.) tensor(0.8627)
# Input: slo torch.Size([1, 1, 512, 512]) tensor(0.) tensor(0.)
# Input: bscanlayermap torch.Size([1, 128, 128]) tensor(0) tensor(0)
# Outputs:
# ...
