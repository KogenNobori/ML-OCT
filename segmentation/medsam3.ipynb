# %% [markdown]
# # MedSAM3

# %%
# !git clone https://github.com/Joey-S-Liu/MedSAM3.git
# %cd MedSAM3
# !pip install -e .
# Out:
# Cloning into 'MedSAM3'...
# remote: Enumerating objects: 647, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Total 647 (delta 9), reused 9 (delta 9), pack-reused 637 (from 2)
# Receiving objects: 100% (647/647), 33.27 MiB | 21.01 MiB/s, done.
# Resolving deltas: 100% (256/256), done.
# /content/MedSAM3
# Obtaining file:///content/MedSAM3
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 3.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 114.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.8/155.8 kB 15.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 89.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.0/76.0 kB 8.3 MB/s eta 0:00:00
# ...

# %%
from huggingface_hub import login
from google.colab import userdata
HF_TOKEN=userdata.get('HF_TOKEN')

if HF_TOKEN:
    login(HF_TOKEN)
    print("Successfully logged in to Hugging Face!")
# Out:
# Successfully logged in to Hugging Face!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install nano
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.4/63.4 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 97.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# Rewrite the configs/full_lora_config.yaml file here. "Please specify the path to your LoRA weights in the configs/full_lora_config.yaml file under the output_dir field."
# It worked if I specify the directory path that contains the file.

# %%
# !python3 infer_sam.py \
  --config configs/full_lora_config.yaml \
  --image /content/drive/MyDrive/research/ML-OCT_datasets/OCT2017/test/NORMAL/NORMAL-1017237-1.jpeg \
  --prompt "retinal layers" \
  --threshold 0.5 \
  --nms-iou 0.5 \
  --output retinal_layers.png
# Out:
# ℹ️  Auto-detected weights: /content/drive/MyDrive/research/ML-OCT_datasets/model_weights/best_lora_weights.pt
# 🔧 Initializing SAM3 + LoRA...
#    Device: cuda
#    Resolution: 1008x1008
#    Confidence threshold: 0.5
#    NMS IoU threshold: 0.5
#
# 📦 Building SAM3 model...
# 🔗 Applying LoRA configuration...
# Replaced 61 nn.MultiheadAttention modules with MultiheadAttentionLoRA
# Applied LoRA to 458 modules:
#   - backbone.vision_backbone.trunk.blocks.0.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.0.attn.proj
#   - backbone.vision_backbone.trunk.blocks.0.mlp.fc1
#   - backbone.vision_backbone.trunk.blocks.0.mlp.fc2
#   - backbone.vision_backbone.trunk.blocks.1.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.1.attn.proj
#   - backbone.vision_backbone.trunk.blocks.1.mlp.fc1
#   - backbone.vision_backbone.trunk.blocks.1.mlp.fc2
#   - backbone.vision_backbone.trunk.blocks.2.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.2.attn.proj
# ...

# %%
# !python3 infer_sam.py \
  --config configs/full_lora_config.yaml \
  --image /content/drive/MyDrive/research/ML-OCT_datasets/OCT2017/test/NORMAL/NORMAL-1017237-1.jpeg \
  --prompt "Ganglion Cell Layer" \
  --threshold 0.5 \
  --nms-iou 0.5 \
  --output GCL.png
# Out:
# ℹ️  Auto-detected weights: /content/drive/MyDrive/research/ML-OCT_datasets/model_weights/best_lora_weights.pt
# 🔧 Initializing SAM3 + LoRA...
#    Device: cuda
#    Resolution: 1008x1008
#    Confidence threshold: 0.5
#    NMS IoU threshold: 0.5
#
# 📦 Building SAM3 model...
# 🔗 Applying LoRA configuration...
# Replaced 61 nn.MultiheadAttention modules with MultiheadAttentionLoRA
# Applied LoRA to 458 modules:
#   - backbone.vision_backbone.trunk.blocks.0.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.0.attn.proj
#   - backbone.vision_backbone.trunk.blocks.0.mlp.fc1
#   - backbone.vision_backbone.trunk.blocks.0.mlp.fc2
#   - backbone.vision_backbone.trunk.blocks.1.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.1.attn.proj
#   - backbone.vision_backbone.trunk.blocks.1.mlp.fc1
#   - backbone.vision_backbone.trunk.blocks.1.mlp.fc2
#   - backbone.vision_backbone.trunk.blocks.2.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.2.attn.proj
# ...

# %%
# !python3 infer_sam.py \
  --config configs/full_lora_config.yaml \
  --image /content/drive/MyDrive/research/ML-OCT_datasets/OCT2017/test/NORMAL/NORMAL-1017237-1.jpeg \
  --prompt "Inner Plexiform Layer" \
  --threshold 0.5 \
  --nms-iou 0.5 \
  --output IPL.png
# Out:
# ℹ️  Auto-detected weights: /content/drive/MyDrive/research/ML-OCT_datasets/model_weights/best_lora_weights.pt
# 🔧 Initializing SAM3 + LoRA...
#    Device: cuda
#    Resolution: 1008x1008
#    Confidence threshold: 0.5
#    NMS IoU threshold: 0.5
#
# 📦 Building SAM3 model...
# 🔗 Applying LoRA configuration...
# Replaced 61 nn.MultiheadAttention modules with MultiheadAttentionLoRA
# Applied LoRA to 458 modules:
#   - backbone.vision_backbone.trunk.blocks.0.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.0.attn.proj
#   - backbone.vision_backbone.trunk.blocks.0.mlp.fc1
#   - backbone.vision_backbone.trunk.blocks.0.mlp.fc2
#   - backbone.vision_backbone.trunk.blocks.1.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.1.attn.proj
#   - backbone.vision_backbone.trunk.blocks.1.mlp.fc1
#   - backbone.vision_backbone.trunk.blocks.1.mlp.fc2
#   - backbone.vision_backbone.trunk.blocks.2.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.2.attn.proj
# ...

# %%
# !python3 infer_sam.py \
  --config configs/full_lora_config.yaml \
  --image /content/drive/MyDrive/research/ML-OCT_datasets/OCT2017/test/NORMAL/NORMAL-1017237-1.jpeg \
  --prompt "Inner Nuclear Layer" \
  --threshold 0.5 \
  --nms-iou 0.5 \
  --output INL.png
# Out:
# ℹ️  Auto-detected weights: /content/drive/MyDrive/research/ML-OCT_datasets/model_weights/best_lora_weights.pt
# 🔧 Initializing SAM3 + LoRA...
#    Device: cuda
#    Resolution: 1008x1008
#    Confidence threshold: 0.5
#    NMS IoU threshold: 0.5
#
# 📦 Building SAM3 model...
# 🔗 Applying LoRA configuration...
# Replaced 61 nn.MultiheadAttention modules with MultiheadAttentionLoRA
# Applied LoRA to 458 modules:
#   - backbone.vision_backbone.trunk.blocks.0.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.0.attn.proj
#   - backbone.vision_backbone.trunk.blocks.0.mlp.fc1
#   - backbone.vision_backbone.trunk.blocks.0.mlp.fc2
#   - backbone.vision_backbone.trunk.blocks.1.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.1.attn.proj
#   - backbone.vision_backbone.trunk.blocks.1.mlp.fc1
#   - backbone.vision_backbone.trunk.blocks.1.mlp.fc2
#   - backbone.vision_backbone.trunk.blocks.2.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.2.attn.proj
# ...

# %%
# !python3 infer_sam.py \
  --config configs/full_lora_config.yaml \
  --image /content/drive/MyDrive/research/ML-OCT_datasets/OCT2017/test/NORMAL/NORMAL-1017237-1.jpeg \
  --prompt "Outer Plexiform Layer" \
  --threshold 0.5 \
  --nms-iou 0.5 \
  --output OPL.png
# Out:
# ℹ️  Auto-detected weights: /content/drive/MyDrive/research/ML-OCT_datasets/model_weights/best_lora_weights.pt
# 🔧 Initializing SAM3 + LoRA...
#    Device: cuda
#    Resolution: 1008x1008
#    Confidence threshold: 0.5
#    NMS IoU threshold: 0.5
#
# 📦 Building SAM3 model...
# 🔗 Applying LoRA configuration...
# Replaced 61 nn.MultiheadAttention modules with MultiheadAttentionLoRA
# Applied LoRA to 458 modules:
#   - backbone.vision_backbone.trunk.blocks.0.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.0.attn.proj
#   - backbone.vision_backbone.trunk.blocks.0.mlp.fc1
#   - backbone.vision_backbone.trunk.blocks.0.mlp.fc2
#   - backbone.vision_backbone.trunk.blocks.1.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.1.attn.proj
#   - backbone.vision_backbone.trunk.blocks.1.mlp.fc1
#   - backbone.vision_backbone.trunk.blocks.1.mlp.fc2
#   - backbone.vision_backbone.trunk.blocks.2.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.2.attn.proj
# ...

# %%
# !python3 infer_sam.py \
  --config configs/full_lora_config.yaml \
  --image /content/drive/MyDrive/research/ML-OCT_datasets/OCT2017/test/NORMAL/NORMAL-1017237-1.jpeg \
  --prompt "Henle Fiber Layer + Outer Nuclear Layer" \
  --threshold 0.5 \
  --nms-iou 0.5 \
  --output HFL_ONL.png
# Out:
# ℹ️  Auto-detected weights: /content/drive/MyDrive/research/ML-OCT_datasets/model_weights/best_lora_weights.pt
# 🔧 Initializing SAM3 + LoRA...
#    Device: cuda
#    Resolution: 1008x1008
#    Confidence threshold: 0.5
#    NMS IoU threshold: 0.5
#
# 📦 Building SAM3 model...
# 🔗 Applying LoRA configuration...
# Replaced 61 nn.MultiheadAttention modules with MultiheadAttentionLoRA
# Applied LoRA to 458 modules:
#   - backbone.vision_backbone.trunk.blocks.0.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.0.attn.proj
#   - backbone.vision_backbone.trunk.blocks.0.mlp.fc1
#   - backbone.vision_backbone.trunk.blocks.0.mlp.fc2
#   - backbone.vision_backbone.trunk.blocks.1.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.1.attn.proj
#   - backbone.vision_backbone.trunk.blocks.1.mlp.fc1
#   - backbone.vision_backbone.trunk.blocks.1.mlp.fc2
#   - backbone.vision_backbone.trunk.blocks.2.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.2.attn.proj
# ...

# %%
# !python3 infer_sam.py \
  --config configs/full_lora_config.yaml \
  --image /content/drive/MyDrive/research/ML-OCT_datasets/OCT2017/test/NORMAL/NORMAL-1017237-1.jpeg \
  --prompt "External Limiting Membrane" \
  --threshold 0.5 \
  --nms-iou 0.5 \
  --output ELM.png
# Out:
# ℹ️  Auto-detected weights: /content/drive/MyDrive/research/ML-OCT_datasets/model_weights/best_lora_weights.pt
# 🔧 Initializing SAM3 + LoRA...
#    Device: cuda
#    Resolution: 1008x1008
#    Confidence threshold: 0.5
#    NMS IoU threshold: 0.5
#
# 📦 Building SAM3 model...
# 🔗 Applying LoRA configuration...
# Replaced 61 nn.MultiheadAttention modules with MultiheadAttentionLoRA
# Applied LoRA to 458 modules:
#   - backbone.vision_backbone.trunk.blocks.0.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.0.attn.proj
#   - backbone.vision_backbone.trunk.blocks.0.mlp.fc1
#   - backbone.vision_backbone.trunk.blocks.0.mlp.fc2
#   - backbone.vision_backbone.trunk.blocks.1.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.1.attn.proj
#   - backbone.vision_backbone.trunk.blocks.1.mlp.fc1
#   - backbone.vision_backbone.trunk.blocks.1.mlp.fc2
#   - backbone.vision_backbone.trunk.blocks.2.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.2.attn.proj
# ...

# %%
# !python3 infer_sam.py \
  --config configs/full_lora_config.yaml \
  --image /content/drive/MyDrive/research/ML-OCT_datasets/OCT2017/test/NORMAL/NORMAL-1017237-1.jpeg \
  --prompt "Layer of Inner Segment and Outer Segment" \
  --threshold 0.5 \
  --nms-iou 0.5 \
  --output EZIZ.png
# Out:
# ℹ️  Auto-detected weights: /content/drive/MyDrive/research/ML-OCT_datasets/model_weights/best_lora_weights.pt
# 🔧 Initializing SAM3 + LoRA...
#    Device: cuda
#    Resolution: 1008x1008
#    Confidence threshold: 0.5
#    NMS IoU threshold: 0.5
#
# 📦 Building SAM3 model...
# 🔗 Applying LoRA configuration...
# Replaced 61 nn.MultiheadAttention modules with MultiheadAttentionLoRA
# Applied LoRA to 458 modules:
#   - backbone.vision_backbone.trunk.blocks.0.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.0.attn.proj
#   - backbone.vision_backbone.trunk.blocks.0.mlp.fc1
#   - backbone.vision_backbone.trunk.blocks.0.mlp.fc2
#   - backbone.vision_backbone.trunk.blocks.1.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.1.attn.proj
#   - backbone.vision_backbone.trunk.blocks.1.mlp.fc1
#   - backbone.vision_backbone.trunk.blocks.1.mlp.fc2
#   - backbone.vision_backbone.trunk.blocks.2.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.2.attn.proj
# ...

# %%
# !python3 infer_sam.py \
  --config configs/full_lora_config.yaml \
  --image /content/drive/MyDrive/research/ML-OCT_datasets/OCT2017/test/NORMAL/NORMAL-1017237-1.jpeg \
  --prompt "Retinal Pigment Epithelium" \
  --threshold 0.5 \
  --nms-iou 0.5 \
  --output RPE.png
# Out:
# ℹ️  Auto-detected weights: /content/drive/MyDrive/research/ML-OCT_datasets/model_weights/best_lora_weights.pt
# 🔧 Initializing SAM3 + LoRA...
#    Device: cuda
#    Resolution: 1008x1008
#    Confidence threshold: 0.5
#    NMS IoU threshold: 0.5
#
# 📦 Building SAM3 model...
# 🔗 Applying LoRA configuration...
# Replaced 61 nn.MultiheadAttention modules with MultiheadAttentionLoRA
# Applied LoRA to 458 modules:
#   - backbone.vision_backbone.trunk.blocks.0.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.0.attn.proj
#   - backbone.vision_backbone.trunk.blocks.0.mlp.fc1
#   - backbone.vision_backbone.trunk.blocks.0.mlp.fc2
#   - backbone.vision_backbone.trunk.blocks.1.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.1.attn.proj
#   - backbone.vision_backbone.trunk.blocks.1.mlp.fc1
#   - backbone.vision_backbone.trunk.blocks.1.mlp.fc2
#   - backbone.vision_backbone.trunk.blocks.2.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.2.attn.proj
# ...

# %%
# !python3 infer_sam.py \
  --config configs/full_lora_config.yaml \
  --image /content/drive/MyDrive/research/ML-OCT_datasets/OCT2017/test/NORMAL/NORMAL-1017237-1.jpeg \
  --prompt "Bruch‘s Membrane" \
  --threshold 0.5 \
  --nms-iou 0.5 \
  --output BM.png
# Out:
# ℹ️  Auto-detected weights: /content/drive/MyDrive/research/ML-OCT_datasets/model_weights/best_lora_weights.pt
# 🔧 Initializing SAM3 + LoRA...
#    Device: cuda
#    Resolution: 1008x1008
#    Confidence threshold: 0.5
#    NMS IoU threshold: 0.5
#
# 📦 Building SAM3 model...
# 🔗 Applying LoRA configuration...
# Replaced 61 nn.MultiheadAttention modules with MultiheadAttentionLoRA
# Applied LoRA to 458 modules:
#   - backbone.vision_backbone.trunk.blocks.0.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.0.attn.proj
#   - backbone.vision_backbone.trunk.blocks.0.mlp.fc1
#   - backbone.vision_backbone.trunk.blocks.0.mlp.fc2
#   - backbone.vision_backbone.trunk.blocks.1.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.1.attn.proj
#   - backbone.vision_backbone.trunk.blocks.1.mlp.fc1
#   - backbone.vision_backbone.trunk.blocks.1.mlp.fc2
#   - backbone.vision_backbone.trunk.blocks.2.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.2.attn.proj
# ...

# %%
# !python3 infer_sam.py \
  --config configs/full_lora_config.yaml \
  --image /content/drive/MyDrive/research/ML-OCT_datasets/OCT2017/test/NORMAL/NORMAL-1017237-1.jpeg \
  --prompt "Choriocapillaris " \
  --threshold 0.5 \
  --nms-iou 0.5 \
  --output CC.png
# Out:
# ℹ️  Auto-detected weights: /content/drive/MyDrive/research/ML-OCT_datasets/model_weights/best_lora_weights.pt
# 🔧 Initializing SAM3 + LoRA...
#    Device: cuda
#    Resolution: 1008x1008
#    Confidence threshold: 0.5
#    NMS IoU threshold: 0.5
#
# 📦 Building SAM3 model...
# 🔗 Applying LoRA configuration...
# Replaced 61 nn.MultiheadAttention modules with MultiheadAttentionLoRA
# Applied LoRA to 458 modules:
#   - backbone.vision_backbone.trunk.blocks.0.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.0.attn.proj
#   - backbone.vision_backbone.trunk.blocks.0.mlp.fc1
#   - backbone.vision_backbone.trunk.blocks.0.mlp.fc2
#   - backbone.vision_backbone.trunk.blocks.1.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.1.attn.proj
#   - backbone.vision_backbone.trunk.blocks.1.mlp.fc1
#   - backbone.vision_backbone.trunk.blocks.1.mlp.fc2
#   - backbone.vision_backbone.trunk.blocks.2.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.2.attn.proj
# ...

# %%
# !python3 infer_sam.py \
  --config configs/full_lora_config.yaml \
  --image /content/drive/MyDrive/research/ML-OCT_datasets/OCT2017/test/NORMAL/NORMAL-1017237-1.jpeg \
  --prompt "Medium and Large Choroidal Vessels " \
  --threshold 0.5 \
  --nms-iou 0.5 \
  --output CV.png
# Out:
# ℹ️  Auto-detected weights: /content/drive/MyDrive/research/ML-OCT_datasets/model_weights/best_lora_weights.pt
# 🔧 Initializing SAM3 + LoRA...
#    Device: cuda
#    Resolution: 1008x1008
#    Confidence threshold: 0.5
#    NMS IoU threshold: 0.5
#
# 📦 Building SAM3 model...
# 🔗 Applying LoRA configuration...
# Replaced 61 nn.MultiheadAttention modules with MultiheadAttentionLoRA
# Applied LoRA to 458 modules:
#   - backbone.vision_backbone.trunk.blocks.0.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.0.attn.proj
#   - backbone.vision_backbone.trunk.blocks.0.mlp.fc1
#   - backbone.vision_backbone.trunk.blocks.0.mlp.fc2
#   - backbone.vision_backbone.trunk.blocks.1.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.1.attn.proj
#   - backbone.vision_backbone.trunk.blocks.1.mlp.fc1
#   - backbone.vision_backbone.trunk.blocks.1.mlp.fc2
#   - backbone.vision_backbone.trunk.blocks.2.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.2.attn.proj
# ...

# %%
# !python3 infer_sam.py \
  --config configs/full_lora_config.yaml \
  --image /content/drive/MyDrive/research/ML-OCT_datasets/OCT2017/test/NORMAL/NORMAL-1017237-1.jpeg \
  --prompt "background " \
  --threshold 0.5 \
  --nms-iou 0.5 \
  --output BG.png
# Out:
# ℹ️  Auto-detected weights: /content/drive/MyDrive/research/ML-OCT_datasets/model_weights/best_lora_weights.pt
# 🔧 Initializing SAM3 + LoRA...
#    Device: cuda
#    Resolution: 1008x1008
#    Confidence threshold: 0.5
#    NMS IoU threshold: 0.5
#
# 📦 Building SAM3 model...
# 🔗 Applying LoRA configuration...
# Replaced 61 nn.MultiheadAttention modules with MultiheadAttentionLoRA
# Applied LoRA to 458 modules:
#   - backbone.vision_backbone.trunk.blocks.0.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.0.attn.proj
#   - backbone.vision_backbone.trunk.blocks.0.mlp.fc1
#   - backbone.vision_backbone.trunk.blocks.0.mlp.fc2
#   - backbone.vision_backbone.trunk.blocks.1.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.1.attn.proj
#   - backbone.vision_backbone.trunk.blocks.1.mlp.fc1
#   - backbone.vision_backbone.trunk.blocks.1.mlp.fc2
#   - backbone.vision_backbone.trunk.blocks.2.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.2.attn.proj
# ...

# %%
# !python3 infer_sam.py \
  --config configs/full_lora_config.yaml \
  --image /content/drive/MyDrive/research/ML-OCT_datasets/OCT2017/test/NORMAL/NORMAL-1017237-1.jpeg \
  --prompt "dark background " \
  --threshold 0.5 \
  --nms-iou 0.5 \
  --output DBG.png
# Out:
# ℹ️  Auto-detected weights: /content/drive/MyDrive/research/ML-OCT_datasets/model_weights/best_lora_weights.pt
# 🔧 Initializing SAM3 + LoRA...
#    Device: cuda
#    Resolution: 1008x1008
#    Confidence threshold: 0.5
#    NMS IoU threshold: 0.5
#
# 📦 Building SAM3 model...
# 🔗 Applying LoRA configuration...
# Replaced 61 nn.MultiheadAttention modules with MultiheadAttentionLoRA
# Applied LoRA to 458 modules:
#   - backbone.vision_backbone.trunk.blocks.0.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.0.attn.proj
#   - backbone.vision_backbone.trunk.blocks.0.mlp.fc1
#   - backbone.vision_backbone.trunk.blocks.0.mlp.fc2
#   - backbone.vision_backbone.trunk.blocks.1.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.1.attn.proj
#   - backbone.vision_backbone.trunk.blocks.1.mlp.fc1
#   - backbone.vision_backbone.trunk.blocks.1.mlp.fc2
#   - backbone.vision_backbone.trunk.blocks.2.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.2.attn.proj
# ...

# %%
# !python3 infer_sam.py \
  --config configs/full_lora_config.yaml \
  --image /content/drive/MyDrive/research/ML-OCT_datasets/OCT2017/test/NORMAL/NORMAL-1025847-1.jpeg \
  --prompt "External Limiting Membrane" \
  --threshold 0.5 \
  --nms-iou 0.5 \
  --output ELM2.png
# Out:
# ℹ️  Auto-detected weights: /content/drive/MyDrive/research/ML-OCT_datasets/model_weights/best_lora_weights.pt
# 🔧 Initializing SAM3 + LoRA...
#    Device: cuda
#    Resolution: 1008x1008
#    Confidence threshold: 0.5
#    NMS IoU threshold: 0.5
#
# 📦 Building SAM3 model...
# 🔗 Applying LoRA configuration...
# Replaced 61 nn.MultiheadAttention modules with MultiheadAttentionLoRA
# Applied LoRA to 458 modules:
#   - backbone.vision_backbone.trunk.blocks.0.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.0.attn.proj
#   - backbone.vision_backbone.trunk.blocks.0.mlp.fc1
#   - backbone.vision_backbone.trunk.blocks.0.mlp.fc2
#   - backbone.vision_backbone.trunk.blocks.1.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.1.attn.proj
#   - backbone.vision_backbone.trunk.blocks.1.mlp.fc1
#   - backbone.vision_backbone.trunk.blocks.1.mlp.fc2
#   - backbone.vision_backbone.trunk.blocks.2.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.2.attn.proj
# ...

# %%
# !python3 infer_sam.py \
  --config configs/full_lora_config.yaml \
  --image /content/drive/MyDrive/research/ML-OCT_datasets/OCT2017/test/NORMAL/NORMAL-1017237-1.jpeg \
  --prompt "RNFL " \
  --threshold 0.5 \
  --nms-iou 0.5 \
  --output RNFL2.png
# Out:
# ℹ️  Auto-detected weights: /content/drive/MyDrive/research/ML-OCT_datasets/model_weights/best_lora_weights.pt
# 🔧 Initializing SAM3 + LoRA...
#    Device: cuda
#    Resolution: 1008x1008
#    Confidence threshold: 0.5
#    NMS IoU threshold: 0.5
#
# 📦 Building SAM3 model...
# 🔗 Applying LoRA configuration...
# Replaced 61 nn.MultiheadAttention modules with MultiheadAttentionLoRA
# Applied LoRA to 458 modules:
#   - backbone.vision_backbone.trunk.blocks.0.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.0.attn.proj
#   - backbone.vision_backbone.trunk.blocks.0.mlp.fc1
#   - backbone.vision_backbone.trunk.blocks.0.mlp.fc2
#   - backbone.vision_backbone.trunk.blocks.1.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.1.attn.proj
#   - backbone.vision_backbone.trunk.blocks.1.mlp.fc1
#   - backbone.vision_backbone.trunk.blocks.1.mlp.fc2
#   - backbone.vision_backbone.trunk.blocks.2.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.2.attn.proj
# ...

# %%
# !python3 infer_sam.py \
  --config configs/full_lora_config.yaml \
  --image /content/drive/MyDrive/research/ML-OCT_datasets/OCT2017/test/NORMAL/NORMAL-1017237-1.jpeg \
  --prompt "choroid " \
  --threshold 0.5 \
  --nms-iou 0.5 \
  --output choroid.png
# Out:
# ℹ️  Auto-detected weights: /content/drive/MyDrive/research/ML-OCT_datasets/model_weights/best_lora_weights.pt
# 🔧 Initializing SAM3 + LoRA...
#    Device: cuda
#    Resolution: 1008x1008
#    Confidence threshold: 0.5
#    NMS IoU threshold: 0.5
#
# 📦 Building SAM3 model...
# 🔗 Applying LoRA configuration...
# Replaced 61 nn.MultiheadAttention modules with MultiheadAttentionLoRA
# Applied LoRA to 458 modules:
#   - backbone.vision_backbone.trunk.blocks.0.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.0.attn.proj
#   - backbone.vision_backbone.trunk.blocks.0.mlp.fc1
#   - backbone.vision_backbone.trunk.blocks.0.mlp.fc2
#   - backbone.vision_backbone.trunk.blocks.1.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.1.attn.proj
#   - backbone.vision_backbone.trunk.blocks.1.mlp.fc1
#   - backbone.vision_backbone.trunk.blocks.1.mlp.fc2
#   - backbone.vision_backbone.trunk.blocks.2.attn.qkv
#   - backbone.vision_backbone.trunk.blocks.2.attn.proj
# ...
