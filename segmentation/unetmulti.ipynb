# %% [markdown]
# Unet-multi

# %%
# !git clone https://github.com/zonasw/unet-nested-multiple-classification.git
# Out:
# Cloning into 'unet-nested-multiple-classification'...
# remote: Enumerating objects: 92, done.
# remote: Counting objects: 100% (92/92), done.
# remote: Compressing objects: 100% (83/83), done.
# remote: Total 92 (delta 31), reused 48 (delta 7), pack-reused 0 (from 0)
# Receiving objects: 100% (92/92), 582.56 KiB | 15.74 MiB/s, done.
# Resolving deltas: 100% (31/31), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir /content/unet-nested-multiple-classification/data

# %%
# !cp -r /content/drive/MyDrive/research/ML-OCT_datasets/oct5k_prepared/exp1/test_img /content/unet-nested-multiple-classification/data/images

# %%
# !cp -r /content/drive/MyDrive/research/ML-OCT_datasets/oct5k_prepared/exp1/test_msk /content/unet-nested-multiple-classification/data/masks

# %%
# %cd unet-nested-multiple-classification
# Out:
# /content/unet-nested-multiple-classification

# %%
# !python train.py
# Out:
# 2026-08-11 17:35:19.361405: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# INFO: Using device cuda
# INFO: Network:
# 	NestedUNet model
# 	3 input channels
# 	3 output channels (classes)
# 	Bilinear upscaling
# INFO: Creating dataset with 307 examples
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# ...
